# %% [markdown]
# ### bind together datasets

# %% [markdown]
# **add the the proposal** We increased the size of the sample by combining the files we downloaded because the data is generated spontaneously. We comdined 3 data sets to get our data set that we will be working on with a sample size of 1200. We made a larger sample because it may result in higher accuracies, since our model will get to be familiar with more examples.

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.1”
# Warning message:
# “package ‘tibble’ was built under R version 4.0.2”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
exams_large<-read_csv("GP_data/exams_large.csv")
#exams_large
exams_small<-read_csv("GP_data/exams_small.csv")
#exams_small
exams_smalle2<-read_csv("GP_data/exams_small2.csv")
#exams_smalle2
# Out:
# Parsed with column specification:
# cols(
#   gender = col_character(),
#   `race/ethnicity` = col_character(),
#   `parental level of education` = col_character(),
#   lunch = col_character(),
#   `test preparation course` = col_character(),
#   `math score` = col_double(),
#   `reading score` = col_double(),
#   `writing score` = col_double()
# )
#
# Parsed with column specification:
# cols(
#   gender = col_character(),
#   `race/ethnicity` = col_character(),
#   `parental level of education` = col_character(),
#   lunch = col_character(),
#   `test preparation course` = col_character(),
#   `math score` = col_double(),
#   `reading score` = col_double(),
#   `writing score` = col_double()
# )
#
# Parsed with column specification:
# cols(
#   gender = col_character(),
#   `race/ethnicity` = col_character(),
#   `parental level of education` = col_character(),
#   lunch = col_character(),
#   `test preparation course` = col_character(),
#   `math score` = col_double(),
# ...

# %%
all_exams<-bind_rows(exams_large, exams_small, exams_smalle2)
all_exams
# Out:
#      gender race/ethnicity parental level of education lunch
# 1    male   group D        some college                standard
# 2    female group E        bachelor's degree           free/reduced
# 3    female group C        some high school            standard
# 4    female group D        associate's degree          free/reduced
# 5    male   group C        some college                free/reduced
# 6    male   group B        some high school            free/reduced
# 7    female group C        associate's degree          standard
# 8    female group D        master's degree             standard
# 9    female group C        high school                 free/reduced
# 10   male   group B        some college                free/reduced
# 11   female group D        associate's degree          standard
# 12   male   group B        high school                 standard
# 13   male   group B        high school                 standard
# ...

# %%
write.csv(all_exams,"GP_data/all_exams.csv")
